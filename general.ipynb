# %%
from evtoltools.common.units import Mass, Power, AngularVelocity

# %%
m = Mass(10)
p = Power(100)

omega = AngularVelocity(5000, 'rpm')

# %%
omega * omega
# Out:
# <Quantity(25000000, 'revolutions_per_minute ** 2')>
